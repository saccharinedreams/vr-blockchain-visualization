# %% [markdown]
# Yahoo Finance
#
# # References:
# # https://medium.com/coinmonks/cryptocurrency-analysis-with-python-load-and-visualize-data-17a26e1b6c9e

# %%
import yfinance as yf
import pandas as pd
import mplfinance as mpf
import matplotlib.pyplot as plt

# %%
# Define the start and end dates for the data
start = '2021-01-01'
end = '2023-04-28'

# Define the list of cryptocurrencies to download
cryptos = ['BTC-USD', 'ETH-USD', 'XRP-USD', 'LTC-USD', 'BCH-USD']

# Use yfinance to download the data for each cryptocurrency 
df_cryptos = yf.download(cryptos, start=start, end=end)

# Select only the close column for every cryptocurrency
df = df_cryptos["Close"]
# Out:
# [*********************100%***********************]  5 of 5 completed

# %%
df.describe()
# Out:
#            BCH-USD       BTC-USD      ETH-USD     LTC-USD     XRP-USD
# count   847.000000    847.000000   847.000000  847.000000  847.000000
# mean    363.718928  35942.684039  2283.622154  126.967837    0.652960
# std     254.532816  13772.058950   954.529457   63.334545    0.320777
# min      89.351791  15787.284180   730.367554   43.300301    0.221655
# 25%     124.724327  22656.510742  1553.361145   71.768108    0.386368
# 50%     326.963348  35791.277344  1936.403442  113.164803    0.532264
# 75%     543.645599  46727.529297  2997.261719  171.046532    0.839174
# max    1542.425049  67566.828125  4812.087402  386.450775    1.839236

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 847 entries, 2021-01-01 to 2023-04-27
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   BCH-USD  847 non-null    float64
#  1   BTC-USD  847 non-null    float64
#  2   ETH-USD  847 non-null    float64
#  3   LTC-USD  847 non-null    float64
#  4   XRP-USD  847 non-null    float64
# dtypes: float64(5)
# memory usage: 39.7 KB

# %%
df
# Out:
#                BCH-USD       BTC-USD      ETH-USD     LTC-USD   XRP-USD
# Date
# 2021-01-01  341.985657  29374.152344   730.367554  126.230347  0.237444
# 2021-01-02  354.599945  32127.267578   774.534973  136.944885  0.221655
# 2021-01-03  421.789856  32782.023438   975.507690  160.190582  0.225848
# 2021-01-04  407.936920  31971.914062  1040.233032  154.807327  0.236677
# 2021-01-05  419.768127  33992.429688  1100.006104  158.594772  0.226750
# ...                ...           ...          ...         ...       ...
# 2023-04-23  119.929192  27591.384766  1862.062012   86.897324  0.465016
# 2023-04-24  119.328468  27525.339844  1842.757446   88.407341  0.461273
# 2023-04-25  120.199104  28307.597656  1866.753662   91.108345  0.469995
# 2023-04-26  117.648354  28422.701172  1866.564209   88.254189  0.462037
# 2023-04-27  117.197548  29473.787109  1908.786377   89.688812  0.466868
#
# [847 rows x 5 columns]

# %%
# Get Bitcoin data from Yahoo Finance
df = yf.download(tickers='BTC-USD', period='2y', interval='1d')

#use Matplotlib to create a line chart of Bitcoin's closing price
df["Close"].plot(figsize=(10,5))
plt.title('Bitcoin Closing Price')
plt.xlabel('Date')
plt.ylabel('Price')
plt.tight_layout()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
# Get Bitcoin data from Yahoo Finance
df = yf.download(tickers='BTC-USD', period='1mo', interval='1d')

# Create candlestick chart
mpf.plot(df, type='candle',  figratio=(12,8), title='BTC-USD',savefig='Candlestick_3.png')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
# Get Bitcoin data from Yahoo Finance
df = yf.download(tickers='BTC-USD', period='2y', interval='1d')

# Plot the volume as a bar chart
plt.figure(figsize=(12, 8))
plt.bar(df.index, df['Volume'], width=0.5, color='gray')
plt.title('Bitcoin Volume')
plt.xlabel('Date')
plt.ylabel('Volume (BTC)')
plt.tight_layout()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
# Get Bitcoin data from Yahoo Finance
df = yf.download(tickers='BTC-USD', period='2y', interval='1d')

# Set up the figure and subplots using gridspec
fig = plt.figure(figsize=(10, 8))
gs = fig.add_gridspec(nrows=5, ncols=1, height_ratios=[3, 1, 1, 1, 1])

# Plot the historical stock prices on the top subplot
ax1 = fig.add_subplot(gs[:3, :])
ax1.plot(df.index, df['Close'])
ax1.set_title('Historical stock prices of BTC-USD')

# Plot the trading volume on the bottom subplot
ax2 = fig.add_subplot(gs[3:, :])
ax2.bar(df.index, df['Volume'])
ax2.set_title('BTC-USD Volume')
plt.tight_layout()
# Out:
# [*********************100%***********************]  1 of 1 completed
